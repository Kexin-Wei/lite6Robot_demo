# %% [markdown]
# # Motion fitting

# %%
import pandas as pd
import numpy as np

# %%
file = "202308011345.csv"
data = pd.read_csv(file)

# %%
data.head
# Out:
# <bound method NDFrame.head of      1690868800.6196463  0.9999990463256836  -0.0013666783925145864  0.0  \
# 0          1.690869e+09            1.000000               -0.000117  0.0
# 1          1.690869e+09            0.999989                0.004693  0.0
# 2          1.690869e+09            0.999996                0.002930  0.0
# 3          1.690869e+09            1.000000                0.000299  0.0
# 4          1.690869e+09            0.999975               -0.007044  0.0
# ..                  ...                 ...                     ...  ...
# 662        1.690869e+09            0.999867                0.016296  0.0
# 663        1.690869e+09            0.999862                0.016593  0.0
# 664        1.690869e+09            0.999929                0.011910  0.0
# 665        1.690869e+09            0.999729                0.023261  0.0
# 666        1.690869e+09            0.999805                0.019724  0.0
#
# ...
